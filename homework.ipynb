# %% [markdown]
# # Home Work 1 - LeeGwanYeop(60185101)

# %% [markdown]
# ## IDE Image

# %% [markdown]
# ![01-2.PNG](attachment:01-2.PNG)

# %% [markdown]
# ## Git 연결

# %% [markdown]
# ![03.PNG](attachment:03.PNG)
#
# #### 연결된 깃에 가보면 다음과 같이 주피터에서 작성된 파일이 push되었습니다.
#
# ![05.PNG](attachment:05.PNG)
#
#
# #### 제가 작성한 코드가 clone 되어있고 주피터 터미널에서 git remote -v를 작성햇을경우 다음과 같이 뜹니다.
#
#
# ![04.PNG](attachment:04.PNG)
